# %% [markdown]
# ![image.png](attachment:7ef123d9-9907-46ae-afe0-72701544db36.png)

# %%
#경로 설정 
import os
print(os.getcwd())
# Out:
# C:\Users\hewo1\AI_class

# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns

import warnings 
warnings.filterwarnings(action='ignore')

# %%
import matplotlib as mat
import matplotlib.font_manager as fonm
mat.rcParams['font.family'] = 'HYPost-Light'

# %%
df = pd.read_csv("dataset/train.csv", encoding='utf-8')
df
# Out:
#               일자 요일  본사정원수  본사휴가자수  본사출장자수  본사시간외근무명령서승인건수  현본사소속재택근무자수  \
# 0     2016-02-01  월   2601      50     150             238          0.0
# 1     2016-02-02  화   2601      50     173             319          0.0
# 2     2016-02-03  수   2601      56     180             111          0.0
# 3     2016-02-04  목   2601     104     220             355          0.0
# 4     2016-02-05  금   2601     278     181              34          0.0
# ...          ... ..    ...     ...     ...             ...          ...
# 1200  2021-01-20  수   2983      75     198               4        391.0
# 1201  2021-01-21  목   2983      92     231             462        351.0
# 1202  2021-01-22  금   2983     255     248               1        303.0
# 1203  2021-01-25  월   2983     107     153             616        327.0
# 1204  2021-01-26  화   2983      69     183             551        362.0
#
#                                                    조식메뉴  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1205 entries, 0 to 1204
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   일자              1205 non-null   object
#  1   요일              1205 non-null   object
#  2   본사정원수           1205 non-null   int64
#  3   본사휴가자수          1205 non-null   int64
#  4   본사출장자수          1205 non-null   int64
#  5   본사시간외근무명령서승인건수  1205 non-null   int64
#  6   현본사소속재택근무자수     1205 non-null   float64
#  7   조식메뉴            1205 non-null   object
#  8   중식메뉴            1205 non-null   object
#  9   석식메뉴            1205 non-null   object
#  10  중식계             1205 non-null   float64
#  11  석식계             1205 non-null   float64
# dtypes: float64(3), int64(4), object(5)
# memory usage: 113.1+ KB

# %%
df_lu_0 = df[df["석식메뉴"]=="*"]
df_lu_0.head()
# Out:
# Empty DataFrame
# Columns: [일자, 요일, 본사정원수, 본사휴가자수, 본사출장자수, 본사시간외근무명령서승인건수, 현본사소속재택근무자수, 조식메뉴, 중식메뉴, 석식메뉴, 중식계, 석식계]
# Index: []

# %%
df.columns
# Out:
# Index(['일자', '요일', '본사정원수', '본사휴가자수', '본사출장자수', '본사시간외근무명령서승인건수',
#        '현본사소속재택근무자수', '조식메뉴', '중식메뉴', '석식메뉴', '중식계', '석식계'],
#       dtype='object')

# %% [markdown]
# # **일자별 점심계와 석식계 분석**

# %%
df.plot(x = '일자', y = ['중식계', '석식계'], figsize = (40, 5))
plt.savefig('plot1.png')

# %% [markdown]
# # **요일별 점심계와 석식계 분석**

# %%
AVG_DAY = (df.groupby('요일')[['중식계', '석식계']].mean())
AVG_DAY["day"] = ["Fri", "Thr", "Wed", "Mon", "Tue"]
AVG_DAY = AVG_DAY.reindex(index=["월", '화', '수', '목', '금'])

plt.plot(AVG_DAY["day"],AVG_DAY["중식계"],'-o',color = 'red', alpha =0.5, label="점심")
plt.plot(AVG_DAY["day"],AVG_DAY["석식계"],'-o',color = 'blue', alpha =0.5, label="저녁")

plt.xlabel("요일", size= 10)
plt.ylabel("사람수", size= 10)
plt.grid()
plt.legend()
plt.savefig('plot2.png')

# %%
df_di_0 = df[df["석식계"]==0]
df_di_0.head()
# Out:
#              일자 요일  본사정원수  본사휴가자수  본사출장자수  본사시간외근무명령서승인건수  현본사소속재택근무자수  \
# 204  2016-11-30  수   2689      68     207               0          0.0
# 224  2016-12-28  수   2705     166     225               0          0.0
# 244  2017-01-25  수   2697      79     203               0          0.0
# 262  2017-02-22  수   2632      75     252               0          0.0
# 281  2017-03-22  수   2627      53     235               0          0.0
#
#                                                   조식메뉴  \
# 204  모닝롤/카스텔라  우유/주스 스크램블에그 누룽지탕/쌀밥 (쌀:국내산) 고추장찌개  ...
# 224  모닝롤/고구마파이  우유/주스 스크램블에그 누룽지탕/쌀밥 (쌀:국내산) 북어계란국 ...
# 244  모닝롤/토마토샌드  우유/주스 계란후라이 누룽지탕/쌀밥 (쌀:국내산) 두부젓국찌개 ...
# 262  모닝롤/브라우니  우유/주스 계란후라이 누룽지탕/쌀밥 (쌀:국내산) 꽃게탕  명엽채...
# 281  모닝롤/찐빵  우유/주스 계란후라이 김치죽/쌀밥 (쌀:국내산) 콩나물국  김실파무침...
#
#                                                   중식메뉴           석식메뉴     중식계  \
# 204  나물비빔밥 (쌀:국내산) 가쯔오장국  치킨핑거*요거트D  감자샐러드  오복지무침  ...      *          1109.0
# ...

# %%
pd.value_counts(df_di_0["요일"])
# Out:
# 수    40
# 금     2
# 화     1
# Name: 요일, dtype: int64

# %%
df_di_0[df_di_0["요일"]=='금']
# Out:
#              일자 요일  본사정원수  본사휴가자수  본사출장자수  본사시간외근무명령서승인건수  현본사소속재택근무자수  \
# 392  2017-09-01  금   2642     177     303              45          0.0
# 412  2017-09-29  금   2642     214     248              22          0.0
#
#                                                   조식메뉴  \
# 392  모닝롤/단팥빵  우유/주스 계란후라이 단호박죽/쌀밥 (쌀:국내산) 대구찌개  깻순나...
# 412  모닝롤/치즈프레즐  우유/주스 계란후라이 홍게살죽/쌀밥 (쌀:국내산) 김치두부국  ...
#
#                                                   중식메뉴           석식메뉴    중식계  \
# 392  쌀밥/잡곡밥 (쌀:국내산) 시래기국  훈제오리구이  두부구이*양념장  쌈무/양파절임...      *          663.0
# 412  쌀밥/잡곡밥 (쌀:국내산) 미역국  쇠불고기/잡채  오징어숙회무침  미니케익/식혜 ...      *          760.0
#
#      석식계
# 392  0.0
# 412  0.0

# %%
df_di_0[df_di_0["요일"]=='화']
# Out:
#              일자 요일  본사정원수  본사휴가자수  본사출장자수  본사시간외근무명령서승인건수  현본사소속재택근무자수  \
# 955  2019-12-31  화   3111     709     149              22          0.0
#
#                                                   조식메뉴  \
# 955  모닝롤/야채샌드  우유/주스 스크램블에그 고구마죽/쌀밥 (쌀:국내산) 열무된장국  ...
#
#                                                   중식메뉴           석식메뉴    중식계  \
# 955  쌀밥/잡곡밥 (쌀:국내산) 배추된장국  닭볶음탕 (닭:국내산) 부추깻잎전  양배추쌈...      *          349.0
#
#      석식계
# 955  0.0

# %%
df_last_wed = df[df["석식계"]>0]

# %%
AVG_DAY1 = (df_last_wed.groupby('요일')[['중식계', '석식계']].mean())
AVG_DAY1["day"] = ["Fri", "Thr", "Wed", "Mon", "Tue"]
AVG_DAY1 = AVG_DAY1.reindex(index=["월", '화', '수', '목', '금'])

plt.plot(AVG_DAY["day"],AVG_DAY["석식계"],'-o',color = 'blue', alpha =0.5, label="저녁")
plt.plot(AVG_DAY1["day"],AVG_DAY1["석식계"],'-o',color = 'orange', alpha =0.5, label="자기개발의날제거")

plt.xlabel("요일", size= 10)
plt.ylabel("사람의 평균", size= 10)
plt.grid()
plt.legend()
plt.savefig('plot3.png')

# %%
# 요일 별 박스 플롯 중식계, 석식계 분포 구하기
boxplot = plt.figure()
axes1 = boxplot.add_subplot(1, 1, 1)
axes1.boxplot([df[df['요일']=='월']['중식계'],
              df[df['요일']=='화']['중식계'],
              df[df['요일']=='수']['중식계'],
              df[df['요일']=='목']['중식계'],
              df[df['요일']=='금']['중식계']],
              labels = ['월','화','수', '목', '금'])
axes1.set_xlabel('요일')
axes1.set_ylabel('점심 먹은 사람수')
plt.savefig('plot4.png')

# %%
boxplot = plt.figure()
axes1 = boxplot.add_subplot(1, 1, 1)
axes1.boxplot([df[df['요일']=='월']['석식계'],
              df[df['요일']=='화']['석식계'],
              df[df['요일']=='수']['석식계'],
              df[df['요일']=='목']['석식계'],
              df[df['요일']=='금']['석식계']],
              labels = ['월','화','수', '목', '금'])
axes1.set_xlabel('요일')
axes1.set_ylabel('저녁 먹은 사람수')
plt.savefig('plot5.png')

# %% [markdown]
# # **중식계, 석식계 빈도수**

# %%
# 중식계, 석식계 빈도수

fig = plt.figure()
ax = fig.add_subplot(1,2,1)

ax.hist(df['중식계'])
ax.set_xlabel('점심')
ax.set_ylabel('빈도수')
ax.grid()

ax = fig.add_subplot(1,2,2)

ax.hist(df['석식계'])
ax.set_xlabel('저녁')
ax.set_ylabel('빈도수')
ax.grid()

fig.tight_layout()
plt.savefig('plot6.png')

# %%
# 휴가자수, 출장자수, 시간외근무명령승인건수, 재택근무자수 빈도수
fig = plt.figure()
ax = fig.add_subplot(2,2,1)

ax.hist(df['본사휴가자수'])
ax.set_xlabel('휴가자수')
ax.set_ylabel('빈도수')
ax.grid()

ax = fig.add_subplot(2,2,2)

ax.hist(df['본사출장자수'])
ax.set_xlabel('출장자수')
ax.set_ylabel('빈도수')
ax.grid()

ax = fig.add_subplot(2,2,3)

ax.hist(df['본사시간외근무명령서승인건수'])
ax.set_xlabel('시간외근무명령승인건수')
ax.set_ylabel('빈도수')
ax.grid()

ax = fig.add_subplot(2,2,4)

ax.hist(df['현본사소속재택근무자수'])
ax.set_xlabel('재택근무자수 빈도수')
ax.set_ylabel('빈도수')
ax.grid()

fig.tight_layout()
plt.savefig('plot7.png')

# %%
# 휴가자수 별 중식계 및 석식계 (scatter)

fig = plt.figure()
ax = fig.add_subplot(1,2,1)

ax.scatter(df['본사휴가자수'], df['중식계'], color = 'r', label = '본사휴가자수와 중식계', alpha = 0.5)

ax.set_xlabel('Number of vacationers')
ax.set_ylabel('Lunch')
ax.grid()

ax = fig.add_subplot(1,2,2)

ax.scatter(df['본사휴가자수'], df['석식계'], color = 'r', label = '본사휴가자수와 석식계', alpha = 0.5)

ax.set_xlabel('Number of vacationers')
ax.set_ylabel('Dinner')
ax.grid()

fig.tight_layout()
plt.savefig('plot8.png')

# %%
ax = plt.subplots()
ax = sns.regplot(x = df['본사휴가자수'], y = df['중식계'])

ax.set_title('Scatterplot of Number of vacationers and Number of Lunch person')
ax.set_xlabel('Number of vacationers')
ax.set_ylabel('Number of Lunch person')
ax.grid()
plt.savefig('plot9.png')

# %%
ax = plt.subplots()
ax = sns.regplot(x = df['본사휴가자수'], y = df['석식계'])

ax.set_title('Scatterplot of Number of vacationers and Number of Dinner person')
ax.set_xlabel('Number of vacationers')
ax.set_ylabel('Number of Dinner person')
ax.grid()
plt.savefig('plot10.png')

# %%
# 휴가자수 별 중식계 및 석식계 (4구간으로 나누어 평균)

df['df_va'] = pd.qcut(df["본사휴가자수"], 4)

fig = plt.figure()

ax = fig.add_subplot(1,2,1)
lunch = df.groupby('df_va')['중식계'].mean()

ax.plot(lunch, '-o')
ax.set_xlabel('Number of vacationers')
ax.set_ylabel('Lunch')
ax.grid()

ax = fig.add_subplot(1,2,2)

dinner = df.groupby('df_va')['석식계'].mean()
ax.plot(dinner, '-o')
ax.set_xlabel('Number of vacationers')
ax.set_ylabel('Dinner')
ax.grid()

fig.tight_layout()
plt.savefig('plot11.png')

# %% [markdown]
# # **점심 메뉴 분석**

# %%
lunch = []
for day in range(len(df)):
    tmp = df.iloc[day, 8].split(' ') # 공백으로 문자열 구분 
    tmp = ' '.join(tmp).split()    # 빈 원소 삭제

    search = '('   # 원산지 정보는 삭제
    for menu in tmp:
        if search in menu:
            tmp.remove(menu)
    
    lunch.append(tmp)

# %%
np.array(df[ (df.index > 1064) & (df.index < 1069)][['일자', '중식메뉴']])
# Out:
# array([['2020-06-11',
#         '쌀밥/잡곡밥 (쌀,현미,흑미:국내산) 매운소고기국  굴비구이  토마토프리타타  도라지오이무침  배추겉절이 (배추국내,고추가루:중국산) '],
#        ['2020-06-12',
#         '돈육버섯고추장덮밥 (쌀,돈육:국내산) 팽이무국  양파링카레튀김  모듬어묵볶음  참나물생채 요구르트 포기김치 (김치:국내산) '],
#        ['2020-07-01',
#         '쌀밥/잡곡밥 냉모밀국수 매운돈갈비찜 메밀전병*간장 고구마순볶음 포기김치 양상추샐러드*딸기요거트 '],
#        ['2020-07-02',
#         '쌀밥/잡곡밥 대파육개장 홍어미나리초무침 어묵잡채 콩자반 배추겉절이 양상추샐러드*오리엔탈 ']],
#       dtype=object)

# %%
# lunch data에 메뉴명별 칼럼 만들기 (밥, 국, 반찬1-3)
bob = []; gook = []; banchan1 = []; banchan2 = []; banchan3 = []; kimchi = []; side = []
for i, day_menu in enumerate(lunch):
    bob_tmp = day_menu[0]; bob.append(bob_tmp)
    gook_tmp = day_menu[1]; gook.append(gook_tmp)
    banchan1_tmp = day_menu[2]; banchan1.append(banchan1_tmp)
    banchan2_tmp = day_menu[3]; banchan2.append(banchan2_tmp)
    banchan3_tmp = day_menu[4]; banchan3.append(banchan3_tmp)

    if i < 1067:
        kimchi_tmp = day_menu[-1]; kimchi.append(kimchi_tmp)
        side_tmp = day_menu[-2]; side.append(side_tmp)
    else: 
        kimchi_tmp = day_menu[-2]; kimchi.append(kimchi_tmp)
        side_tmp  = day_menu[-1]; side.append(side_tmp)

# %%
df_ln = df[['일자', '요일', '본사정원수', '본사휴가자수', '본사출장자수', '본사시간외근무명령서승인건수',
       '현본사소속재택근무자수', '중식메뉴', '중식계']]
df_ln['bob'] = bob
df_ln['gook'] = gook
df_ln['banchan1'] = banchan1; df_ln['banchan2'] = banchan2; df_ln['banchan3'] = banchan3
df_ln['kimchi'] = kimchi 
df_ln['side'] = side

# %%
df_ln.iloc[1066:1070, 7:]
# Out:
#                                                    중식메뉴    중식계        bob  \
# 1066  돈육버섯고추장덮밥 (쌀,돈육:국내산) 팽이무국  양파링카레튀김  모듬어묵볶음  참나...  516.0  돈육버섯고추장덮밥
# 1067  쌀밥/잡곡밥 냉모밀국수 매운돈갈비찜 메밀전병*간장 고구마순볶음 포기김치 양상추샐러드...  866.0     쌀밥/잡곡밥
# 1068  쌀밥/잡곡밥 대파육개장 홍어미나리초무침 어묵잡채 콩자반 배추겉절이 양상추샐러드*오리엔탈   675.0     쌀밥/잡곡밥
# 1069     카레라이스 동태알탕 부추고추전*간장 쫄면야채무침 과일요거트샐러드 포기김치 요구르트   607.0      카레라이스
#
#        gook  banchan1 banchan2  banchan3 kimchi          side
# 1066   팽이무국   양파링카레튀김   모듬어묵볶음     참나물생채   포기김치          요구르트
# 1067  냉모밀국수    매운돈갈비찜  메밀전병*간장    고구마순볶음   포기김치  양상추샐러드*딸기요거트
# 1068  대파육개장  홍어미나리초무침     어묵잡채       콩자반  배추겉절이   양상추샐러드*오리엔탈
# 1069   동태알탕  부추고추전*간장   쫄면야채무침  과일요거트샐러드   포기김치          요구르트

# %%
pd.value_counts(df_ln['bob'])
# Out:
# 쌀밥/잡곡밥          879
# 쌀밥/흑미밥/찰현미밥      74
# 콩나물밥             23
# 카레덮밥             18
# 나물비빔밥            15
#                ...
# 오므라이스             1
# 오곡밥               1
# 새우날치알볶음밥          1
# 호박된장국             1
# 쌀밥/강낭콩밥/찰현미밥      1
# Name: bob, Length: 75, dtype: int64

# %%
pd.value_counts(df_ln['gook'])
# Out:
# 맑은국        46
# 콩나물국       44
# 된장찌개       37
# 어묵국        31
# 아욱국        28
#            ..
# 복숭아미역냉국     1
# 들깨무채국       1
# 청양된장찌개      1
# 한방갈비탕       1
# 쑥된장국        1
# Name: gook, Length: 272, dtype: int64

# %%
pd.value_counts(df_ln['banchan1'])
# Out:
# 오징어볶음        32
# 닭갈비          30
# 버섯불고기        29
# 훈제오리구이       27
# 돈육굴소스볶음      25
#              ..
# 깻잎통닭*치킨소스     1
# 돼지고기유자청볶음     1
# 칠리새우          1
# 매콤떡갈비조림       1
# 개성감자만두        1
# Name: banchan1, Length: 391, dtype: int64

# %%
pd.value_counts(df_ln['banchan2'])
# Out:
# 계란말이         27
# 새송이버섯전       24
# 계란찜          24
# 우엉잡채         18
# 메추리알조림       18
#              ..
# 두부&김치볶음       1
# 상추쌈/고추/마늘     1
# 콘치즈오븐구이       1
# 실곤약냉채         1
# 비빔메밀국수        1
# Name: banchan2, Length: 465, dtype: int64

# %%
pd.value_counts(df_ln['banchan3'])
# Out:
# 오이무침       34
# 콩나물무침      28
# 숙주나물       24
# 무생채        22
# 시금치나물      19
#            ..
# 버섯볶음        1
# 군고구마/과일     1
# 고구마줄기볶음     1
# 매운어묵볶음      1
# 부추호박전       1
# Name: banchan3, Length: 447, dtype: int64

# %%
df["중식계"].describe()
# Out:
# count    1205.000000
# mean      890.334440
# std       209.505057
# min       296.000000
# 25%       758.000000
# 50%       879.000000
# 75%      1032.000000
# max      1459.000000
# Name: 중식계, dtype: float64

# %%
df[df["중식계"]==296]
# Out:
#              일자 요일  본사정원수  본사휴가자수  본사출장자수  본사시간외근무명령서승인건수  현본사소속재택근무자수  \
# 705  2018-12-24  월   2846     894     159              26          0.0
#
#                                                   조식메뉴  \
# 705  모닝롤/프렌치토스트  우유/주스 계란후라이 누룽지탕/쌀밥 (쌀:국내산) 콩나물김치국...
#
#                                                   중식메뉴  \
# 705  쌀밥/잡곡밥 (쌀:국내산) 열무된장국  훈제오리구이  매운어묵볶음  쌈무/부추생채 ...
#
#                                                   석식메뉴    중식계    석식계  \
# 705  쌀밥/잡곡밥 (쌀:국내산) 민물새우찌개  닭갈비  버섯잡채  오이무침  포기김치 (...  296.0  104.0
#
#                df_va
# 705  (185.0, 1224.0]

# %%
df[df["석식계"]==104]
# Out:
#              일자 요일  본사정원수  본사휴가자수  본사출장자수  본사시간외근무명령서승인건수  현본사소속재택근무자수  \
# 705  2018-12-24  월   2846     894     159              26          0.0
#
#                                                   조식메뉴  \
# 705  모닝롤/프렌치토스트  우유/주스 계란후라이 누룽지탕/쌀밥 (쌀:국내산) 콩나물김치국...
#
#                                                   중식메뉴  \
# 705  쌀밥/잡곡밥 (쌀:국내산) 열무된장국  훈제오리구이  매운어묵볶음  쌈무/부추생채 ...
#
#                                                   석식메뉴    중식계    석식계  \
# 705  쌀밥/잡곡밥 (쌀:국내산) 민물새우찌개  닭갈비  버섯잡채  오이무침  포기김치 (...  296.0  104.0
#
#                df_va
# 705  (185.0, 1224.0]

# %%
df["석식계"].describe()
# Out:
# count    1205.000000
# mean      461.772614
# std       139.179202
# min         0.000000
# 25%       406.000000
# 50%       483.000000
# 75%       545.000000
# max       905.000000
# Name: 석식계, dtype: float64

# %%
df["본사휴가자수"].describe()
# Out:
# count    1205.000000
# mean      157.913693
# std       144.190572
# min        23.000000
# 25%        71.000000
# 50%       105.000000
# 75%       185.000000
# max      1224.000000
# Name: 본사휴가자수, dtype: float64

# %%
df[df["석식계"]>0].describe()
# Out:
#              본사정원수       본사휴가자수       본사출장자수  본사시간외근무명령서승인건수  현본사소속재택근무자수  \
# count  1162.000000  1162.000000  1162.000000     1162.000000  1162.000000
# mean   2808.351979   158.805508   240.697935      284.169535    44.783133
# std     171.481589   144.692409    43.688004      245.036722   111.185156
# min    2601.000000    23.000000    41.000000        0.000000     0.000000
# 25%    2645.000000    72.000000   217.000000       11.250000     0.000000
# 50%    2760.000000   105.000000   244.000000      310.000000     0.000000
# 75%    2962.000000   188.000000   272.000000      458.000000     0.000000
# max    3305.000000  1224.000000   378.000000     1044.000000   533.000000
#
#                중식계          석식계
# count  1162.000000  1162.000000
# mean    891.472461   478.860585
# std     210.923623   109.080178
# min     296.000000   104.000000
# 25%     757.250000   415.250000
# 50%     880.000000   486.500000
# 75%    1033.000000   548.000000
# max    1459.000000   905.000000

# %%
df[df["석식계"]==905]["석식메뉴"]
# Out:
# 164    쌀밥/잡곡밥 (쌀:국내산) 순두부찌개  미니함박조림 (쇠고기:호주산,돈육:국내산) ...
# Name: 석식메뉴, dtype: object

# %%
df_ln[df_ln["중식계"]==1459]['중식메뉴']
# Out:
# 735    쌀밥/잡곡밥 (쌀:국내산) 어묵국  소불고기 (소고기:호주산) 계란말이  실곤약초무...
# Name: 중식메뉴, dtype: object

# %%
df_ln[df_ln["banchan1"]=="소불고기"]['중식계']
# Out:
# 27       958.0
# 141     1258.0
# 172     1196.0
# 258      968.0
# 325     1193.0
# 475     1178.0
# 602     1061.0
# 617     1092.0
# 665     1156.0
# 735     1459.0
# 816     1232.0
# 826     1105.0
# 895     1215.0
# 1001    1276.0
# 1108     784.0
# Name: 중식계, dtype: float64

# %% [markdown]
# # 워드클라우드 시도

# %%
#Wordcloud
from wordcloud import WordCloud

# %%
wc = WordCloud(font_path='font/NanumGothic.ttf',
    background_color="white",
    width=1000,
    height=1000,
    max_words=100,
    max_font_size=300)

# %%
ln_banchan1 = []
for i in df_ln["banchan1"]:
    ln_banchan1.append(i)
lu_ban1 = ' '.join(ln_banchan1)
type(lu_ban1)
# Out:
# str

# %%
wc.generate(lu_ban1)

# %%
plt.figure(figsize=(22,22)) #이미지 사이즈 지정
plt.imshow(wc, interpolation='lanczos') #이미지의 부드럽기 정도
plt.axis('off') #x y 축 숫자 제거
plt.savefig("plot12.png")

# %%
plt.figure(figsize = (10, 10))
corr_mat = df.corr(method='pearson')
sns.heatmap(corr_mat, xticklabels = corr_mat.columns, yticklabels = corr_mat.columns, annot=True, cmap='YlGnBu')
plt.savefig("plot13.png")
